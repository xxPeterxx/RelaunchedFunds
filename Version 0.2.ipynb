# %% [markdown]
# Relaunched Hedge Funds
# ==
#
# This program is a replication of Stata Script Version 0.2

# %%
import pandas as pd

# ****************** Program Settings ******************
Folder 		= "~/Dropbox/Projects/2015 - Lippers Tass Relaunched Hedge Funds/"		 # Location of program scripts
Data 		= "~/Workspace/Temp/"								 # // Location to which temporary files are generated
DataSource  = "~/Dropbox/Resources/Datasets/Lippers Tass/Tass_Access_13/"		 # // Location of the original data files (ASCII)
# ******************************************************

# %% [markdown]
# # Prepare Data

# %%
# Load manager details
data_manager = pd.read_stata(DataSource + 'PeopleDetails.dta')
data_manager = data_manager[data_manager.PersonTypeID==1]
variables_to_keep = "ProductReference PersonID First Last JobTitle Address1 Address2 Address3 CityName StateName Zip CountryName".split()
data_manager = data_manager[variables_to_keep]
data_manager.head()
# Out:
#     ProductReference  PersonID   First        Last             JobTitle  \
# 1                  5      2508  Robert    Thompson    Portfolio Manager
# 4                  8       139  Enrico  Massignani  Performance Contact
# 6                  9       139  Enrico  Massignani  Performance Contact
# 9                 10       139  Enrico  Massignani  Performance Contact
# 11                11       139  Enrico  Massignani  Performance Contact
#
#              Address1 Address2 Address3 CityName StateName    Zip  \
# 1   3351 W Bearss Ave                      Tampa   Florida  33618
# 4     Via Ugo Bassi 6                      Milan      None  20159
# 6     Via Ugo Bassi 6                      Milan      None  20159
# 9     Via Ugo Bassi 6                      Milan      None  20159
# 11    Via Ugo Bassi 6                      Milan      None  20159
#
#       CountryName
# 1   United States
# 4           Italy
# 6           Italy
# 9           Italy
# 11          Italy

# %%
# Extract Inception / PerformnaceEndData date
data_dates = pd.read_stata(DataSource + 'ProductDetails.dta')
variables_to_keep = "ProductReference InceptionDate PerformanceEndDate".split()
data_dates = data_dates[variables_to_keep]
data_dates.head()
# Out:
#    ProductReference InceptionDate PerformanceEndDate
# 0                86    1993-01-01         2013-09-30
# 1                87    1992-01-01         2008-09-30
# 2                90    1993-07-01         1997-12-31
# 3                91    1993-07-01         1997-12-31
# 4                92    1993-07-01         2000-12-31

# %% [markdown]
# # Analysis

# %% [markdown]
# Merge managers with the start/end dates

# %%
# Inner join - non-matches are excluded
data_merged = data_manager.merge(data_dates, on='ProductReference', how='inner')
data_merged = data_merged.sort(columns=['PersonID', 
                                        'PerformanceEndDate', 
                                        'InceptionDate',
                                        'ProductReference'])
data_merged.head()
# Out:
#       ProductReference  PersonID    First       Last   JobTitle  \
# 1197              1763         4  Douglas        Bry  President
# 312                637         4  Douglas        Bry  President
# 1120              1679         4  Douglas        Bry  President
# 1856              2508         9   Jerald  Weintraub     (none)
# 2314              3721         9   Jerald  Weintraub     (none)
#
#                         Address1   Address2 Address3       CityName  \
# 1197  3609 South Wadsworth Blvd.  Suite 250                  Denver
# 312   3609 South Wadsworth Blvd.  Suite 250                  Denver
# 1120  3609 South Wadsworth Blvd.  Suite 250                  Denver
# 1856       900 Montgomery Street                      San Francisco
# 2314       900 Montgomery Street                      San Francisco
#
#        StateName    Zip    CountryName InceptionDate PerformanceEndDate
# 1197    Colorado  80235  United States    1996-08-01         1998-03-31
# 312     Colorado  80235  United States    1991-03-01         2011-03-31
# 1120    Colorado  80235  United States    1991-03-01         2011-03-31
# 1856  California  94133  United States    1992-05-08         2006-10-31
# 2314  California  94133  United States    1998-11-18         2007-05-31

# %% [markdown]
# Find **First End Date** for each PersonID.

# %%
# Create a GroupBy object
grouped = data_merged[['PersonID', 'PerformanceEndDate']].groupby('PersonID', axis=0)  # these will aplit the DataFrame on its index (rows).
grouped.groups
print(grouped.get_group(4))
grouped.min()

# Find the smallest value in the end date for each PersonID
transformed = grouped.min()
transformed['first_end_date'] = transformed['PerformanceEndDate']
transformed = transformed.drop('PerformanceEndDate', axis=1)

# Merge back
print(data_merged.PersonID.head())
print(type(transformed))
print(type(data_merged))
data_merged = data_merged.merge(transformed, how='outer', 
                                left_on='PersonID', right_index=True)
data_merged = data_merged.rename(columns={
    'first_end_date_x': 'first_end_date'
    }).drop('first_end_date_y', axis=1)
data_merged.head()
# Out:
#       PersonID PerformanceEndDate
# 1197         4         1998-03-31
# 312          4         2011-03-31
# 1120         4         2011-03-31
# 1197    4
# 312     4
# 1120    4
# 1856    9
# 2314    9
# Name: PersonID, dtype: int32
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#       ProductReference  PersonID    First       Last   JobTitle  \
# 1197              1763         4  Douglas        Bry  President
# 312                637         4  Douglas        Bry  President
# 1120              1679         4  Douglas        Bry  President
# 1856              2508         9   Jerald  Weintraub     (none)
# 2314              3721         9   Jerald  Weintraub     (none)
#
#                         Address1   Address2 Address3       CityName  \
# 1197  3609 South Wadsworth Blvd.  Suite 250                  Denver
# 312   3609 South Wadsworth Blvd.  Suite 250                  Denver
# 1120  3609 South Wadsworth Blvd.  Suite 250                  Denver
# 1856       900 Montgomery Street                      San Francisco
# 2314       900 Montgomery Street                      San Francisco
#
#        StateName    Zip    CountryName InceptionDate PerformanceEndDate  \
# 1197    Colorado  80235  United States    1996-08-01         1998-03-31
# 312     Colorado  80235  United States    1991-03-01         2011-03-31
# 1120    Colorado  80235  United States    1991-03-01         2011-03-31
# 1856  California  94133  United States    1992-05-08         2006-10-31
# 2314  California  94133  United States    1998-11-18         2007-05-31
#
#      first_end_date first_end_date first_end_date first_end_date
# 1197     1998-03-31     1998-03-31     1998-03-31     1998-03-31
# 312      1998-03-31     1998-03-31     1998-03-31     1998-03-31
# 1120     1998-03-31     1998-03-31     1998-03-31     1998-03-31
# 1856     2006-10-31     2006-10-31     2006-10-31     2006-10-31
# 2314     2006-10-31     2006-10-31     2006-10-31     2006-10-31

# %%
# Out:
#          PerformanceEndDate
# PersonID
# 4                1998-03-31
# 9                2006-10-31
# 11               1997-04-30
# 15               1999-08-31
# 19               2002-03-31
# 22               2013-09-30
# 25               2004-11-30
# 26               2004-11-30
# 27               2004-11-30
# 29               2006-06-30
# 31               2005-12-31
# 33               2012-12-31
# 35               2008-02-29
# 37               1999-03-31
# 39               1999-09-30
# 41               2000-07-31
# 42               2000-07-31
# 43               2004-09-30
# 45               2003-08-31
# 49               2000-03-31
# 50               2000-03-31
# 51               1996-06-30
# 55               2000-04-30
# 56               2001-08-31
# 62               2006-03-31
# 66               2000-09-30
# 70               2001-03-31
# 76               2005-08-31
# 77               1995-06-30
# 79               2008-04-30
# ...                     ...
# 32211            2013-06-30
# 32212            2013-05-31
# 32213            2013-05-31
# 32214            2013-05-31
# 32215            2013-05-31
# 32218            2013-07-31
# 32221            2013-09-30
# 32222            2013-08-31
# 32227            2013-09-30
# 32228            2013-09-30
# 32231            2013-07-31
# 32233            2013-08-31
# 32235            2013-08-31
# 32236            2013-08-31
# 32237            2013-08-31
# 32238            2013-07-31
# 32239            2013-08-31
# 32242            2013-09-30
# 32243            2013-07-31
# 32253            2013-09-30
# 32256            2013-09-30
# 32261            2013-07-31
# 32264            2013-07-31
# 32268            2013-07-31
# 32270            2013-09-30
# 32279            2013-09-30
# 32285            2013-09-30
# 32289            2011-06-30
# 32300            2013-09-30
# 32302            2013-09-30
#
# [5802 rows x 1 columns]
